# %% [markdown]
# # Handling missing data
#
# Missing values reflect a data generation process: values are missing for a reason. We need to understand (or at least hypothesize) why data is missing to choose missing value imputation methods that are
# - statistically valid
# - avoid introducing bias
#
# ## Classical categories of missingness
# ### MCAR — Missing Completely At Random
# **Interpretation**: Whether a value is missing is unrelated to anything in the dataset.
#
# **Example scenarios**
#
# - A random software glitch causes some rows to be dropped entirely.
#
# - A sensor occasionally fails independent of environmental conditions.
#
# - Survey forms were lost in the mail randomly.
#
# **Practical implication**
#
# Under MCAR, analyzing only complete cases does not create systematic bias (but reduces sample size and efficiency), thus
#
# - Complete case analysis is often acceptable (unbiased) but wastes data.
# - Imputation tends to work well; many simple methods are “good enough.”
#
# ### MAR — Missing At Random
# Interpretation: Missingness is “explainable” using variables we actually observed.
#
# Example scenarios
#
# - In a survey, people in certain known groups are less likely to answer income questions.
#
#   - Example: for respondents with observed education level / age group, salary nonresponse differs.
#
# - In simulation experiments, the model crashes for certain observed input conditions.
#
#   - Example: for large observed parameter values, the simulation becomes unstable and output becomes missing.
#
# Practical implication
#
# - Under MAR, methods that properly condition on predictors can still be valid. If missingness is independent of the response conditional on the predictors, linear regression remains valid (conceptually: conditioning blocks the dependence).
#
# - Naive imputation may distort relationships depending on the analysis goal.
#
# - But imputation methods can introduce bias, depending on:
#
#   - whether the imputation uses the response variable,
#
#   - whether your analysis depends on correlations/variance (most do),
#
#   - whether uncertainty is propagated.
#
#
#
# ### MNAR — Missing Not At Random
# Interpretation: Missingness is informative about the missing value.
#
# **Example scenarios**
#
# - Pollutant sensor detection limit: the sensor only records values above a threshold; low values are “missing.”
#
#   - Here missingness depends on the actual (unobserved) pollutant concentration.
#
# - Storm surges only occur in areas below water level
#
#   - The surge measurements are missing in regions that never become inundated; missingness depends on latent flood conditions.
#
# **Practical implication**
#
# - Under MNAR, missingness itself must be modeled explicitly.
#
#   - For example, censored observations in survival analysis, where the censoring mechanism is part of the model.
#
# - Standard imputation can lead to strong bias unless missingness is handled carefully.

# %% [markdown]
# ## Imputation experiment
# We impute missing values for column `ActualElapsedTime` from `airline_2019.csv` using:
# - constant imputation
# - MICE (iterative imputer with posterior sampling; PMM if `miceforest` is available)
# - k-nearest neighbors (KNN) imputation
#
# We compare methods using:
# - RMSE and correlation on a held-out missingness mask (numeric columns only)
# - correlation matrix preservation

# %%
import pandas as pd
import missingno as msno # gives information about missing values
import miceforest as mf 
import plotnine
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer, SimpleImputer

# %%
## Change the file location to your saved location
FILE_LOCATION = '/Users/liviafingerson/Desktop/GitHub/de300-2026wi-fingerson/labs/airline_2019.csv'

# %%
USE_COLS = [
    "Year",
    "Month",
    "DayofMonth",
    "DayOfWeek",
    "DepTime",
    "CRSDepTime",
    "ArrTime",
    "CRSArrTime",
    "Reporting_Airline",
    "Flight_Number_Reporting_Airline",
    "Tail_Number",
    "ActualElapsedTime",
    "CRSElapsedTime",
    "AirTime",
    "ArrDelay",
    "DepDelay",
    "Origin",
    "Dest",
    "Distance",
    "TaxiIn",
    "TaxiOut",
    "Cancelled",
    "CancellationCode",
    "Diverted",
    "CarrierDelay",
    "WeatherDelay",
    "NASDelay",
    "SecurityDelay",
    "LateAircraftDelay",
]

# %%
df_2019 = pd.read_csv(FILE_LOCATION, usecols = USE_COLS)

# %%
numeric_cols = df_2019.select_dtypes(include="number").columns.tolist()
categorical_cols = [c for c in USE_COLS if c not in numeric_cols]

# %%
categorical_cols
# Out:
# ['Reporting_Airline', 'Tail_Number', 'Origin', 'Dest', 'CancellationCode']

# %%
missing_summary = df_2019[USE_COLS].isna().mean().sort_values(ascending=False)
missing_summary
# Out:
# CancellationCode                   0.981675
# LateAircraftDelay                  0.813159
# SecurityDelay                      0.813159
# NASDelay                           0.813159
# WeatherDelay                       0.813159
# CarrierDelay                       0.813159
# ActualElapsedTime                  0.020805
# AirTime                            0.020805
# ArrDelay                           0.020805
# TaxiIn                             0.018795
# ArrTime                            0.018795
# TaxiOut                            0.018195
# DepTime                            0.017581
# DepDelay                           0.017581
# Tail_Number                        0.002741
# CRSElapsedTime                     0.000039
# Cancelled                          0.000000
# DayofMonth                         0.000000
# DayOfWeek                          0.000000
# CRSDepTime                         0.000000
# Diverted                           0.000000
# Flight_Number_Reporting_Airline    0.000000
# Distance                           0.000000
# Dest                               0.000000
# Origin                             0.000000
# Month                              0.000000
# CRSArrTime                         0.000000
# Reporting_Airline                  0.000000
# Year                               0.000000
# dtype: float64

# %%
msno.bar(df_2019)
msno.matrix(df_2019)
# Out:
# <Axes: >

# %% [markdown]
# ### Build Holdout Mask
# It a boolean mask (same shape as your dataframe) that marks a random subset of currently-observed entries to be held out / artificially treated as missing.
#
# This performs the similar function as removing whole column data in class example. This is to enable us to compre imputed and roginal true values and calculated metrics (e.g., RMSE).

# %%
# only discards from target columns

import numpy as np

target_col = "ActualElapsedTime" # choose subset of columns to have pretend missing data
seed = 42
missing_rate = 0.10 

rng = np.random.default_rng(seed)
observed_mask = df_2019[target_col].notna()
holdout_mask = (rng.random(len(df_2019)) < missing_rate) & observed_mask

df_masked = df_2019.copy()
df_masked.loc[holdout_mask, target_col] = np.nan

holdout_mask.sum()
# Out:
# 7399

# %% [markdown]
# ### Method 1: Simple Imputation with a constant

# %%
df_2019.loc[holdout_mask, [target_col]].head()
# Out:
#     ActualElapsedTime
# 4                65.0
# 17              166.0
# 27              127.0
# 68              123.0
# 74              116.0

# %%
df_masked[target_col].median()
# Out:
# 119.0

# %%
# Constant imputation
constant_fill = df_2019[target_col].median()
df_const = df_masked.copy()
df_const[target_col] = df_const[target_col].fillna(constant_fill)
df_const[target_col].isna().sum()
df_const[target_col].describe()
# Out:
# count    76616.000000
# mean       134.482562
# std         68.336504
# min         16.000000
# 25%         88.000000
# 50%        119.000000
# 75%        159.000000
# max        665.000000
# Name: ActualElapsedTime, dtype: float64

# %%
# calculating rmse

def evaluate_method(label, df_imputed):
    y_true = df_2019.loc[holdout_mask, target_col].astype(float)
    y_pred = df_imputed.loc[holdout_mask, target_col].astype(float)
    valid = y_true.notna() & y_pred.notna()

    if valid.sum() == 0:
        rmse = np.nan
        corr = np.nan
    else:
        rmse = float(np.sqrt(np.mean((y_true[valid] - y_pred[valid]) ** 2)))
        corr = float(np.corrcoef(y_true[valid], y_pred[valid])[0, 1])

    return {"method": label, "rmse": rmse}

# %%
evaluate_method("Constant", df_const)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
# {'method': 'Constant', 'rmse': 75.19771479448166}

# %%
corr = df_2019.select_dtypes('number').corr()
corr_const = df_const.select_dtypes('number').corr()

corr - corr_const # difference between two matrices
# Out:
#                                  Year     Month  DayofMonth  DayOfWeek  \
# Year                              NaN       NaN         NaN        NaN
# Month                             NaN  0.000000    0.000000   0.000000
# DayofMonth                        NaN  0.000000    0.000000   0.000000
# DayOfWeek                         NaN  0.000000    0.000000   0.000000
# Flight_Number_Reporting_Airline   NaN  0.000000    0.000000   0.000000
# CRSDepTime                        NaN  0.000000    0.000000   0.000000
# DepTime                           NaN  0.000000    0.000000   0.000000
# DepDelay                          NaN  0.000000    0.000000   0.000000
# TaxiOut                           NaN  0.000000    0.000000   0.000000
# TaxiIn                            NaN  0.000000    0.000000   0.000000
# CRSArrTime                        NaN  0.000000    0.000000   0.000000
# ArrTime                           NaN  0.000000    0.000000   0.000000
# ArrDelay                          NaN  0.000000    0.000000   0.000000
# Cancelled                         NaN  0.000000    0.000000   0.000000
# Diverted                          NaN  0.000000    0.000000   0.000000
# CRSElapsedTime                    NaN  0.000000    0.000000   0.000000
# ActualElapsedTime                 NaN -0.003221   -0.000542   0.001187
# AirTime                           NaN  0.000000    0.000000   0.000000
# Distance                          NaN  0.000000    0.000000   0.000000
# CarrierDelay                      NaN  0.000000    0.000000   0.000000
# WeatherDelay                      NaN  0.000000    0.000000   0.000000
# NASDelay                          NaN  0.000000    0.000000   0.000000
# SecurityDelay                     NaN  0.000000    0.000000   0.000000
# LateAircraftDelay                 NaN  0.000000    0.000000   0.000000
#
#                                  Flight_Number_Reporting_Airline  CRSDepTime  \
# Year                                                         NaN         NaN
# Month                                                   0.000000    0.000000
# DayofMonth                                              0.000000    0.000000
# DayOfWeek                                               0.000000    0.000000
# Flight_Number_Reporting_Airline                         0.000000    0.000000
# CRSDepTime                                              0.000000    0.000000
# DepTime                                                 0.000000    0.000000
# DepDelay                                                0.000000    0.000000
# TaxiOut                                                 0.000000    0.000000
# TaxiIn                                                  0.000000    0.000000
# CRSArrTime                                              0.000000    0.000000
# ArrTime                                                 0.000000    0.000000
# ArrDelay                                                0.000000    0.000000
# Cancelled                                               0.000000    0.000000
# Diverted                                                0.000000    0.000000
# CRSElapsedTime                                          0.000000    0.000000
# ActualElapsedTime                                      -0.019281   -0.001437
# AirTime                                                 0.000000    0.000000
# Distance                                                0.000000    0.000000
# CarrierDelay                                            0.000000    0.000000
# WeatherDelay                                            0.000000    0.000000
# NASDelay                                                0.000000    0.000000
# SecurityDelay                                           0.000000    0.000000
# LateAircraftDelay                                       0.000000    0.000000
#
#                                   DepTime  DepDelay  TaxiOut    TaxiIn  ...  \
# Year                                  NaN       NaN      NaN       NaN  ...
# Month                            0.000000  0.000000  0.00000  0.000000  ...
# DayofMonth                       0.000000  0.000000  0.00000  0.000000  ...
# DayOfWeek                        0.000000  0.000000  0.00000  0.000000  ...
# Flight_Number_Reporting_Airline  0.000000  0.000000  0.00000  0.000000  ...
# CRSDepTime                       0.000000  0.000000  0.00000  0.000000  ...
# DepTime                          0.000000  0.000000  0.00000  0.000000  ...
# DepDelay                         0.000000  0.000000  0.00000  0.000000  ...
# TaxiOut                          0.000000  0.000000  0.00000  0.000000  ...
# TaxiIn                           0.000000  0.000000  0.00000  0.000000  ...
# CRSArrTime                       0.000000  0.000000  0.00000  0.000000  ...
# ArrTime                          0.000000  0.000000  0.00000  0.000000  ...
# ArrDelay                         0.000000  0.000000  0.00000  0.000000  ...
# Cancelled                        0.000000  0.000000  0.00000       NaN  ...
# Diverted                         0.000000  0.000000  0.00000  0.000000  ...
# CRSElapsedTime                   0.000000  0.000000  0.00000  0.000000  ...
# ActualElapsedTime               -0.002751  0.001512  0.01106  0.012004  ...
# AirTime                          0.000000  0.000000  0.00000  0.000000  ...
# Distance                         0.000000  0.000000  0.00000  0.000000  ...
# CarrierDelay                     0.000000  0.000000  0.00000  0.000000  ...
# WeatherDelay                     0.000000  0.000000  0.00000  0.000000  ...
# NASDelay                         0.000000  0.000000  0.00000  0.000000  ...
# SecurityDelay                    0.000000  0.000000  0.00000  0.000000  ...
# LateAircraftDelay                0.000000  0.000000  0.00000  0.000000  ...
#
#                                  Diverted  CRSElapsedTime  ActualElapsedTime  \
# Year                                  NaN             NaN                NaN
# Month                                 0.0        0.000000          -0.003221
# DayofMonth                            0.0        0.000000          -0.000542
# DayOfWeek                             0.0        0.000000           0.001187
# Flight_Number_Reporting_Airline       0.0        0.000000          -0.019281
# CRSDepTime                            0.0        0.000000          -0.001437
# DepTime                               0.0        0.000000          -0.002751
# DepDelay                              0.0        0.000000           0.001512
# TaxiOut                               0.0        0.000000           0.011060
# TaxiIn                                0.0        0.000000           0.012004
# CRSArrTime                            0.0        0.000000           0.001223
# ArrTime                               0.0        0.000000           0.001016
# ArrDelay                              NaN        0.000000           0.002486
# Cancelled                             0.0        0.000000                NaN
# Diverted                              0.0        0.000000                NaN
# CRSElapsedTime                        0.0        0.000000           0.060079
# ActualElapsedTime                     NaN        0.060079           0.000000
# AirTime                               NaN        0.000000           0.053373
# Distance                              0.0        0.000000           0.058434
# CarrierDelay                          NaN        0.000000          -0.002188
# WeatherDelay                          NaN        0.000000          -0.002354
# NASDelay                              NaN        0.000000           0.004232
# SecurityDelay                         NaN        0.000000          -0.000635
# LateAircraftDelay                     NaN        0.000000          -0.007663
#
#                                   AirTime  Distance  CarrierDelay  \
# Year                                  NaN       NaN           NaN
# Month                            0.000000  0.000000      0.000000
# DayofMonth                       0.000000  0.000000      0.000000
# DayOfWeek                        0.000000  0.000000      0.000000
# Flight_Number_Reporting_Airline  0.000000  0.000000      0.000000
# CRSDepTime                       0.000000  0.000000      0.000000
# DepTime                          0.000000  0.000000      0.000000
# DepDelay                         0.000000  0.000000      0.000000
# TaxiOut                          0.000000  0.000000      0.000000
# TaxiIn                           0.000000  0.000000      0.000000
# CRSArrTime                       0.000000  0.000000      0.000000
# ArrTime                          0.000000  0.000000      0.000000
# ArrDelay                         0.000000  0.000000      0.000000
# Cancelled                             NaN  0.000000           NaN
# Diverted                              NaN  0.000000           NaN
# CRSElapsedTime                   0.000000  0.000000      0.000000
# ActualElapsedTime                0.053373  0.058434     -0.002188
# AirTime                          0.000000  0.000000      0.000000
# Distance                         0.000000  0.000000      0.000000
# CarrierDelay                     0.000000  0.000000      0.000000
# WeatherDelay                     0.000000  0.000000      0.000000
# NASDelay                         0.000000  0.000000      0.000000
# SecurityDelay                    0.000000  0.000000      0.000000
# LateAircraftDelay                0.000000  0.000000      0.000000
#
#                                  WeatherDelay  NASDelay  SecurityDelay  \
# Year                                      NaN       NaN            NaN
# Month                                0.000000  0.000000       0.000000
# DayofMonth                           0.000000  0.000000       0.000000
# DayOfWeek                            0.000000  0.000000       0.000000
# Flight_Number_Reporting_Airline      0.000000  0.000000       0.000000
# CRSDepTime                           0.000000  0.000000       0.000000
# DepTime                              0.000000  0.000000       0.000000
# DepDelay                             0.000000  0.000000       0.000000
# TaxiOut                              0.000000  0.000000       0.000000
# TaxiIn                               0.000000  0.000000       0.000000
# CRSArrTime                           0.000000  0.000000       0.000000
# ArrTime                              0.000000  0.000000       0.000000
# ArrDelay                             0.000000  0.000000       0.000000
# Cancelled                                 NaN       NaN            NaN
# Diverted                                  NaN       NaN            NaN
# CRSElapsedTime                       0.000000  0.000000       0.000000
# ActualElapsedTime                   -0.002354  0.004232      -0.000635
# AirTime                              0.000000  0.000000       0.000000
# Distance                             0.000000  0.000000       0.000000
# CarrierDelay                         0.000000  0.000000       0.000000
# WeatherDelay                         0.000000  0.000000       0.000000
# NASDelay                             0.000000  0.000000       0.000000
# SecurityDelay                        0.000000  0.000000       0.000000
# LateAircraftDelay                    0.000000  0.000000       0.000000
#
#                                  LateAircraftDelay
# Year                                           NaN
# Month                                     0.000000
# DayofMonth                                0.000000
# DayOfWeek                                 0.000000
# Flight_Number_Reporting_Airline           0.000000
# CRSDepTime                                0.000000
# DepTime                                   0.000000
# DepDelay                                  0.000000
# TaxiOut                                   0.000000
# TaxiIn                                    0.000000
# CRSArrTime                                0.000000
# ArrTime                                   0.000000
# ArrDelay                                  0.000000
# Cancelled                                      NaN
# Diverted                                       NaN
# CRSElapsedTime                            0.000000
# ActualElapsedTime                        -0.007663
# AirTime                                   0.000000
# Distance                                  0.000000
# CarrierDelay                              0.000000
# WeatherDelay                              0.000000
# NASDelay                                  0.000000
# SecurityDelay                             0.000000
# LateAircraftDelay                         0.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# ### Method 2: MICE (PMM) with miceforest
# key function
# ```python
# kernel = mf.ImputationKernel(
#     df_masked[numeric_cols].astype(float),
#     datasets=1,
#     save_all_iterations=False,
#     random_state=seed,
#     mean_match_candidates=5,
# )
# kernel.mice(mice_iters)
# df_mice_num = kernel.complete_data(dataset=0)
# ```

# %%
def corr_diff_func(imputed_df):
    corr_orig = df_2019.select_dtypes('number').corr()
    corr_imputed = imputed_df.select_dtypes('number').corr()

    corr_diff = corr_orig - corr_imputed

    print(f'\nDifference in correlation matrices between the original dataset and the imputed df:\n')
    display(corr_diff)

    #return corr_diff

# %%
mice_iters = 5 # number of iterations

kernel = mf.ImputationKernel(
    df_masked[numeric_cols].astype(float),
    num_datasets=1,
    random_state=seed,
    mean_match_candidates=5,
)
kernel.mice(mice_iters)

df_mice_num = kernel.complete_data(dataset=0)

# %%
evaluate_method("MICE", df_mice_num)
# Out:
# {'method': 'MICE', 'rmse': 7.444210667979017}

# %%
corr_diff_func(df_mice_num)
# Out:
# Difference in correlation matrices between the original dataset and the imputed df:
#                                  Year     Month  DayofMonth     DayOfWeek  \
# Year                              NaN       NaN         NaN           NaN
# Month                             NaN  0.000000    0.000000  0.000000e+00
# DayofMonth                        NaN  0.000000    0.000000  0.000000e+00
# DayOfWeek                         NaN  0.000000    0.000000  0.000000e+00
# Flight_Number_Reporting_Airline   NaN  0.000000    0.000000  0.000000e+00
# CRSDepTime                        NaN  0.000000    0.000000  0.000000e+00
# DepTime                           NaN  0.000014   -0.000306 -5.747399e-04
# DepDelay                          NaN -0.002639   -0.000456  1.944020e-03
# TaxiOut                           NaN  0.009149   -0.004576 -1.230198e-03
# TaxiIn                            NaN  0.020124   -0.007718  3.563673e-03
# CRSArrTime                        NaN  0.000000    0.000000  0.000000e+00
# ArrTime                           NaN -0.000202   -0.000109 -3.285134e-04
# ArrDelay                          NaN -0.001828    0.000094 -3.801994e-04
# Cancelled                         NaN  0.000000    0.000000  0.000000e+00
# Diverted                          NaN  0.000000    0.000000  0.000000e+00
# CRSElapsedTime                    NaN -0.000047   -0.000003  6.989202e-07
# ActualElapsedTime                 NaN -0.002379    0.000702  6.552322e-05
# AirTime                           NaN -0.001661    0.000715  1.775806e-04
# Distance                          NaN  0.000000    0.000000  0.000000e+00
# CarrierDelay                      NaN  0.011587    0.005404  5.006547e-03
# WeatherDelay                      NaN -0.007807   -0.007153 -2.269293e-03
# NASDelay                          NaN -0.000858    0.004277 -2.909248e-03
# SecurityDelay                     NaN  0.019325    0.032117 -5.816632e-03
# LateAircraftDelay                 NaN  0.008667   -0.002904 -3.944728e-03
#
#                                  Flight_Number_Reporting_Airline  CRSDepTime  \
# Year                                                         NaN         NaN
# Month                                                   0.000000    0.000000
# DayofMonth                                              0.000000    0.000000
# DayOfWeek                                               0.000000    0.000000
# Flight_Number_Reporting_Airline                         0.000000    0.000000
# CRSDepTime                                              0.000000    0.000000
# DepTime                                                -0.001395    0.000617
# DepDelay                                               -0.005035   -0.003361
# TaxiOut                                                -0.004202   -0.012813
# TaxiIn                                                 -0.016309   -0.022107
# CRSArrTime                                              0.000000    0.000000
# ArrTime                                                -0.001784    0.003520
# ArrDelay                                               -0.002324   -0.000747
# Cancelled                                               0.000000    0.000000
# Diverted                                                0.000000    0.000000
# CRSElapsedTime                                          0.000018   -0.000001
# ActualElapsedTime                                      -0.000248   -0.000028
# AirTime                                                -0.000891    0.000096
# Distance                                                0.000000    0.000000
# CarrierDelay                                            0.006541   -0.058369
# WeatherDelay                                            0.017065    0.010956
# NASDelay                                               -0.002103   -0.045851
# SecurityDelay                                           0.009484    0.031030
# LateAircraftDelay                                       0.026667    0.022785
#
#                                   DepTime  DepDelay   TaxiOut    TaxiIn  ...  \
# Year                                  NaN       NaN       NaN       NaN  ...
# Month                            0.000014 -0.002639  0.009149  0.020124  ...
# DayofMonth                      -0.000306 -0.000456 -0.004576 -0.007718  ...
# DayOfWeek                       -0.000575  0.001944 -0.001230  0.003564  ...
# Flight_Number_Reporting_Airline -0.001395 -0.005035 -0.004202 -0.016309  ...
# CRSDepTime                       0.000617 -0.003361 -0.012813 -0.022107  ...
# DepTime                          0.000000  0.000237 -0.008883 -0.016676  ...
# DepDelay                         0.000237  0.000000 -0.044987 -0.067529  ...
# TaxiOut                         -0.008883 -0.044987  0.000000 -0.155577  ...
# TaxiIn                          -0.016676 -0.067529 -0.155577  0.000000  ...
# CRSArrTime                       0.000030 -0.002220 -0.006538 -0.011963  ...
# ArrTime                          0.001392  0.000969  0.001654  0.000470  ...
# ArrDelay                         0.000727  0.024368  0.007997  0.010223  ...
# Cancelled                       -0.004959 -0.109759 -0.227537       NaN  ...
# Diverted                         0.000132  0.001689  0.002603  0.007361  ...
# CRSElapsedTime                  -0.000012  0.002995  0.012215  0.024767  ...
# ActualElapsedTime               -0.000494  0.002383  0.023748  0.043596  ...
# AirTime                         -0.000435  0.001368  0.006138  0.014928  ...
# Distance                         0.000202  0.003312  0.009833  0.021382  ...
# CarrierDelay                    -0.069015  0.023536 -0.075356 -0.049520  ...
# WeatherDelay                     0.000869  0.075118  0.005086 -0.018982  ...
# NASDelay                        -0.033900 -0.021057  0.025655  0.033749  ...
# SecurityDelay                    0.039869  0.064812  0.039695  0.031687  ...
# LateAircraftDelay                0.000247 -0.094922 -0.157848 -0.079365  ...
#
#                                  Diverted  CRSElapsedTime  ActualElapsedTime  \
# Year                                  NaN             NaN                NaN
# Month                            0.000000   -4.682071e-05          -0.002379
# DayofMonth                       0.000000   -2.996978e-06           0.000702
# DayOfWeek                        0.000000    6.989202e-07           0.000066
# Flight_Number_Reporting_Airline  0.000000    1.848488e-05          -0.000248
# CRSDepTime                       0.000000   -1.139146e-06          -0.000028
# DepTime                          0.000132   -1.179771e-05          -0.000494
# DepDelay                         0.001689    2.995448e-03           0.002383
# TaxiOut                          0.002603    1.221465e-02           0.023748
# TaxiIn                           0.007361    2.476745e-02           0.043596
# CRSArrTime                       0.000000    8.317298e-07           0.000084
# ArrTime                         -0.001086   -3.311353e-04          -0.000049
# ArrDelay                              NaN    1.167003e-03           0.001330
# Cancelled                        0.000000    1.789304e-04                NaN
# Diverted                         0.000000   -1.275348e-06                NaN
# CRSElapsedTime                  -0.000001    0.000000e+00           0.000143
# ActualElapsedTime                     NaN    1.434832e-04           0.000000
# AirTime                               NaN    1.731080e-04           0.000690
# Distance                         0.000000   -3.987004e-07          -0.000067
# CarrierDelay                          NaN    2.952923e-03          -0.028041
# WeatherDelay                          NaN   -1.192720e-02          -0.012052
# NASDelay                              NaN    7.722655e-03           0.052321
# SecurityDelay                         NaN    5.555244e-03           0.009436
# LateAircraftDelay                     NaN   -4.221515e-02          -0.096540
#
#                                   AirTime      Distance  CarrierDelay  \
# Year                                  NaN           NaN           NaN
# Month                           -0.001661  0.000000e+00      0.011587
# DayofMonth                       0.000715  0.000000e+00      0.005404
# DayOfWeek                        0.000178  0.000000e+00      0.005007
# Flight_Number_Reporting_Airline -0.000891  0.000000e+00      0.006541
# CRSDepTime                       0.000096  0.000000e+00     -0.058369
# DepTime                         -0.000435  2.017124e-04     -0.069015
# DepDelay                         0.001368  3.312216e-03      0.023536
# TaxiOut                          0.006138  9.833111e-03     -0.075356
# TaxiIn                           0.014928  2.138210e-02     -0.049520
# CRSArrTime                      -0.000098  0.000000e+00     -0.054203
# ArrTime                         -0.000181 -2.480445e-04     -0.050458
# ArrDelay                         0.001301  1.382799e-03      0.038968
# Cancelled                             NaN  0.000000e+00           NaN
# Diverted                              NaN  0.000000e+00           NaN
# CRSElapsedTime                   0.000173 -3.987004e-07      0.002953
# ActualElapsedTime                0.000690 -6.698523e-05     -0.028041
# AirTime                          0.000000  1.948813e-04     -0.007696
# Distance                         0.000195  0.000000e+00      0.004040
# CarrierDelay                    -0.007696  4.039711e-03      0.000000
# WeatherDelay                    -0.014642 -1.460676e-02     -0.071969
# NASDelay                         0.013596 -1.385404e-03     -0.066974
# SecurityDelay                    0.003255  2.886867e-03     -0.091336
# LateAircraftDelay               -0.062991 -4.338111e-02     -0.124952
#
#                                  WeatherDelay  NASDelay  SecurityDelay  \
# Year                                      NaN       NaN            NaN
# Month                               -0.007807 -0.000858       0.019325
# DayofMonth                          -0.007153  0.004277       0.032117
# DayOfWeek                           -0.002269 -0.002909      -0.005817
# Flight_Number_Reporting_Airline      0.017065 -0.002103       0.009484
# CRSDepTime                           0.010956 -0.045851       0.031030
# DepTime                              0.000869 -0.033900       0.039869
# DepDelay                             0.075118 -0.021057       0.064812
# TaxiOut                              0.005086  0.025655       0.039695
# TaxiIn                              -0.018982  0.033749       0.031687
# CRSArrTime                           0.011302 -0.014633       0.026332
# ArrTime                              0.001520  0.000914       0.028244
# ArrDelay                             0.094085  0.013094       0.072850
# Cancelled                                 NaN       NaN            NaN
# Diverted                                  NaN       NaN            NaN
# CRSElapsedTime                      -0.011927  0.007723       0.005555
# ActualElapsedTime                   -0.012052  0.052321       0.009436
# AirTime                             -0.014642  0.013596       0.003255
# Distance                            -0.014607 -0.001385       0.002887
# CarrierDelay                        -0.071969 -0.066974      -0.091336
# WeatherDelay                         0.000000 -0.061144      -0.203619
# NASDelay                            -0.061144  0.000000      -0.063909
# SecurityDelay                       -0.203619 -0.063909       0.000000
# LateAircraftDelay                   -0.040500 -0.096569       0.002071
#
#                                  LateAircraftDelay
# Year                                           NaN
# Month                                     0.008667
# DayofMonth                               -0.002904
# DayOfWeek                                -0.003945
# Flight_Number_Reporting_Airline           0.026667
# CRSDepTime                                0.022785
# DepTime                                   0.000247
# DepDelay                                 -0.094922
# TaxiOut                                  -0.157848
# TaxiIn                                   -0.079365
# CRSArrTime                                0.000321
# ArrTime                                  -0.063537
# ArrDelay                                 -0.114586
# Cancelled                                      NaN
# Diverted                                       NaN
# CRSElapsedTime                           -0.042215
# ActualElapsedTime                        -0.096540
# AirTime                                  -0.062991
# Distance                                 -0.043381
# CarrierDelay                             -0.124952
# WeatherDelay                             -0.040500
# NASDelay                                 -0.096569
# SecurityDelay                             0.002071
# LateAircraftDelay                         0.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# ### Method 3: KNN imputation
# Key function
# ```python
# knn_imputer = KNNImputer(n_neighbors=knn_k)
#
# df_knn_num = pd.DataFrame(
#     knn_imputer.fit_transform(df_masked[numeric_cols].astype(float)),
#     columns=numeric_cols,
#     index=df_masked.index,
# )
#
# ```

# %%
knn_k = 5 # number of neighbors

knn_imputer = KNNImputer(n_neighbors=knn_k)

df_knn_num = pd.DataFrame(
    knn_imputer.fit_transform(df_masked[numeric_cols].astype(float)),
    columns=numeric_cols,
    index=df_masked.index,
)

# %%
evaluate_method("KNN", df_knn_num)
# Out:
# {'method': 'KNN', 'rmse': 15.395505756979128}

# %%
corr_diff_func(df_knn_num)
# Out:
# Difference in correlation matrices between the original dataset and the imputed df:
#                                  Year     Month  DayofMonth     DayOfWeek  \
# Year                              NaN       NaN         NaN           NaN
# Month                             NaN  0.000000    0.000000  0.000000e+00
# DayofMonth                        NaN  0.000000    0.000000  0.000000e+00
# DayOfWeek                         NaN  0.000000    0.000000  0.000000e+00
# Flight_Number_Reporting_Airline   NaN  0.000000    0.000000  0.000000e+00
# CRSDepTime                        NaN  0.000000    0.000000  0.000000e+00
# DepTime                           NaN  0.000264   -0.000530 -6.252114e-04
# DepDelay                          NaN -0.000077   -0.000246 -2.016254e-05
# TaxiOut                           NaN -0.000457    0.000296 -2.603601e-04
# TaxiIn                            NaN -0.000182   -0.000314  2.299304e-04
# CRSArrTime                        NaN  0.000000    0.000000  0.000000e+00
# ArrTime                           NaN  0.000479   -0.000668 -6.888398e-04
# ArrDelay                          NaN -0.001162   -0.000132 -8.672693e-04
# Cancelled                         NaN  0.000000    0.000000  0.000000e+00
# Diverted                          NaN  0.000000    0.000000  0.000000e+00
# CRSElapsedTime                    NaN -0.000046   -0.000003  1.895953e-07
# ActualElapsedTime                 NaN -0.003373    0.000996 -4.110616e-04
# AirTime                           NaN -0.002321    0.000898 -2.295531e-05
# Distance                          NaN  0.000000    0.000000  0.000000e+00
# CarrierDelay                      NaN  0.013944    0.004273  6.301066e-03
# WeatherDelay                      NaN -0.007761   -0.001901 -9.975650e-04
# NASDelay                          NaN  0.000752    0.009113 -5.406485e-03
# SecurityDelay                     NaN  0.006473   -0.003902  1.285873e-02
# LateAircraftDelay                 NaN  0.008496   -0.004786 -3.064191e-03
#
#                                  Flight_Number_Reporting_Airline  CRSDepTime  \
# Year                                                         NaN         NaN
# Month                                                   0.000000    0.000000
# DayofMonth                                              0.000000    0.000000
# DayOfWeek                                               0.000000    0.000000
# Flight_Number_Reporting_Airline                         0.000000    0.000000
# CRSDepTime                                              0.000000    0.000000
# DepTime                                                -0.001899   -0.000638
# DepDelay                                               -0.000208   -0.000900
# TaxiOut                                                -0.000954   -0.000734
# TaxiIn                                                 -0.000435   -0.000166
# CRSArrTime                                              0.000000    0.000000
# ArrTime                                                -0.002197   -0.002180
# ArrDelay                                               -0.000768   -0.001244
# Cancelled                                               0.000000    0.000000
# Diverted                                                0.000000    0.000000
# CRSElapsedTime                                          0.000018   -0.000003
# ActualElapsedTime                                       0.000036    0.000193
# AirTime                                                -0.000386    0.000560
# Distance                                                0.000000    0.000000
# CarrierDelay                                            0.012487   -0.042880
# WeatherDelay                                            0.014022   -0.012800
# NASDelay                                               -0.002705    0.049961
# SecurityDelay                                           0.011760    0.028352
# LateAircraftDelay                                       0.010784   -0.092760
#
#                                   DepTime  DepDelay   TaxiOut    TaxiIn  ...  \
# Year                                  NaN       NaN       NaN       NaN  ...
# Month                            0.000264 -0.000077 -0.000457 -0.000182  ...
# DayofMonth                      -0.000530 -0.000246  0.000296 -0.000314  ...
# DayOfWeek                       -0.000625 -0.000020 -0.000260  0.000230  ...
# Flight_Number_Reporting_Airline -0.001899 -0.000208 -0.000954 -0.000435  ...
# CRSDepTime                      -0.000638 -0.000900 -0.000734 -0.000166  ...
# DepTime                          0.000000 -0.000782 -0.000690 -0.000234  ...
# DepDelay                        -0.000782  0.000000  0.000140  0.000203  ...
# TaxiOut                         -0.000690  0.000140  0.000000 -0.000173  ...
# TaxiIn                          -0.000234  0.000203 -0.000173  0.000000  ...
# CRSArrTime                      -0.001076 -0.000677 -0.000423 -0.000446  ...
# ArrTime                         -0.002355 -0.001307 -0.000411 -0.000600  ...
# ArrDelay                        -0.000443  0.001285  0.001407 -0.000319  ...
# Cancelled                       -0.011719  0.023207 -0.001557       NaN  ...
# Diverted                         0.000182  0.000056  0.000061  0.004078  ...
# CRSElapsedTime                   0.000315  0.000137  0.000354 -0.000190  ...
# ActualElapsedTime               -0.000530 -0.000432  0.011853  0.007602  ...
# AirTime                          0.000325  0.000569  0.000350  0.000141  ...
# Distance                         0.000492  0.000138  0.000331 -0.000199  ...
# CarrierDelay                    -0.051529  0.053689 -0.060462 -0.033627  ...
# WeatherDelay                    -0.023055  0.016225 -0.011517 -0.011846  ...
# NASDelay                         0.057883 -0.002283  0.041129  0.045889  ...
# SecurityDelay                    0.031455  0.000803 -0.000397  0.003688  ...
# LateAircraftDelay               -0.106573 -0.028091 -0.110569 -0.043660  ...
#
#                                  Diverted  CRSElapsedTime  ActualElapsedTime  \
# Year                                  NaN             NaN                NaN
# Month                            0.000000   -4.640782e-05          -0.003373
# DayofMonth                       0.000000   -2.540627e-06           0.000996
# DayOfWeek                        0.000000    1.895953e-07          -0.000411
# Flight_Number_Reporting_Airline  0.000000    1.810101e-05           0.000036
# CRSDepTime                       0.000000   -2.669946e-06           0.000193
# DepTime                          0.000182    3.145194e-04          -0.000530
# DepDelay                         0.000056    1.369128e-04          -0.000432
# TaxiOut                          0.000061    3.537654e-04           0.011853
# TaxiIn                           0.004078   -1.902496e-04           0.007602
# CRSArrTime                       0.000000   -8.255949e-07          -0.000130
# ArrTime                         -0.001969   -9.021159e-05           0.000413
# ArrDelay                              NaN    4.675882e-04           0.003020
# Cancelled                        0.000000    1.770682e-04                NaN
# Diverted                         0.000000   -1.257183e-06                NaN
# CRSElapsedTime                  -0.000001    0.000000e+00          -0.000129
# ActualElapsedTime                     NaN   -1.285751e-04           0.000000
# AirTime                               NaN    1.170738e-04           0.000111
# Distance                         0.000000   -3.547469e-07          -0.001706
# CarrierDelay                          NaN   -2.035749e-02          -0.047533
# WeatherDelay                          NaN   -1.696110e-02          -0.020408
# NASDelay                              NaN   -3.891232e-02           0.011034
# SecurityDelay                         NaN    2.654457e-03          -0.002060
# LateAircraftDelay                     NaN   -2.143222e-02          -0.067701
#
#                                   AirTime      Distance  CarrierDelay  \
# Year                                  NaN           NaN           NaN
# Month                           -0.002321  0.000000e+00      0.013944
# DayofMonth                       0.000898  0.000000e+00      0.004273
# DayOfWeek                       -0.000023  0.000000e+00      0.006301
# Flight_Number_Reporting_Airline -0.000386  0.000000e+00      0.012487
# CRSDepTime                       0.000560  0.000000e+00     -0.042880
# DepTime                          0.000325  4.922887e-04     -0.051529
# DepDelay                         0.000569  1.380472e-04      0.053689
# TaxiOut                          0.000350  3.310676e-04     -0.060462
# TaxiIn                           0.000141 -1.991026e-04     -0.033627
# CRSArrTime                       0.000302  0.000000e+00     -0.003348
# ArrTime                          0.000099 -2.864948e-05     -0.032618
# ArrDelay                         0.000554  4.842091e-04      0.077218
# Cancelled                             NaN  0.000000e+00           NaN
# Diverted                              NaN  0.000000e+00           NaN
# CRSElapsedTime                   0.000117 -3.547469e-07     -0.020357
# ActualElapsedTime                0.000111 -1.705833e-03     -0.047533
# AirTime                          0.000000 -8.773189e-05     -0.029661
# Distance                        -0.000088  0.000000e+00     -0.022703
# CarrierDelay                    -0.029661 -2.270328e-02      0.000000
# WeatherDelay                    -0.019821 -1.879986e-02     -0.025452
# NASDelay                        -0.030283 -4.501030e-02     -0.021316
# SecurityDelay                   -0.000849  3.394479e-03     -0.000131
# LateAircraftDelay               -0.040366 -2.677672e-02     -0.067875
#
#                                  WeatherDelay  NASDelay  SecurityDelay  \
# Year                                      NaN       NaN            NaN
# Month                               -0.007761  0.000752       0.006473
# DayofMonth                          -0.001901  0.009113      -0.003902
# DayOfWeek                           -0.000998 -0.005406       0.012859
# Flight_Number_Reporting_Airline      0.014022 -0.002705       0.011760
# CRSDepTime                          -0.012800  0.049961       0.028352
# DepTime                             -0.023055  0.057883       0.031455
# DepDelay                             0.016225 -0.002283       0.000803
# TaxiOut                             -0.011517  0.041129      -0.000397
# TaxiIn                              -0.011846  0.045889       0.003688
# CRSArrTime                           0.006000  0.059719       0.022095
# ArrTime                             -0.016206  0.050226       0.026481
# ArrDelay                             0.036353  0.024944      -0.000556
# Cancelled                                 NaN       NaN            NaN
# Diverted                                  NaN       NaN            NaN
# CRSElapsedTime                      -0.016961 -0.038912       0.002654
# ActualElapsedTime                   -0.020408  0.011034      -0.002060
# AirTime                             -0.019821 -0.030283      -0.000849
# Distance                            -0.018800 -0.045010       0.003394
# CarrierDelay                        -0.025452 -0.021316      -0.000131
# WeatherDelay                         0.000000 -0.021918      -0.000425
# NASDelay                            -0.021918  0.000000      -0.000051
# SecurityDelay                       -0.000425 -0.000051       0.000000
# LateAircraftDelay                   -0.035450 -0.027500       0.004788
#
#                                  LateAircraftDelay
# Year                                           NaN
# Month                                     0.008496
# DayofMonth                               -0.004786
# DayOfWeek                                -0.003064
# Flight_Number_Reporting_Airline           0.010784
# CRSDepTime                               -0.092760
# DepTime                                  -0.106573
# DepDelay                                 -0.028091
# TaxiOut                                  -0.110569
# TaxiIn                                   -0.043660
# CRSArrTime                               -0.036407
# ArrTime                                  -0.142677
# ArrDelay                                 -0.030451
# Cancelled                                      NaN
# Diverted                                       NaN
# CRSElapsedTime                           -0.021432
# ActualElapsedTime                        -0.067701
# AirTime                                  -0.040366
# Distance                                 -0.026777
# CarrierDelay                             -0.067875
# WeatherDelay                             -0.035450
# NASDelay                                 -0.027500
# SecurityDelay                             0.004788
# LateAircraftDelay                         0.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# ### Results:
#
# RMSE - constant: 75.19771479448166
#
# RMSE - KNN: 15.395505756979128
#
# RMSE - MICE: 7.444210667979017
#
# MICE has the lowest RMSE. The differences in correlation seem to be very low, at least not noticeably different from the differences for the KNN imputation method. From this, MICE is the best imputation method for this problem.

# %% [markdown]
# ## Summary/Takeaways
# In practice:
#
# - MCAR → complete-case or simple imputation often okay
#
# - MAR → regression/likelihood-based methods can be valid; naive imputation can bias results
#
# - MNAR → must model missingness explicitly (or do sensitivity analysis)
#
# Imputation quality should be evaluated both by:
#
# - predictive error (e.g., RMSE when truth is known),
#
# - structure preservation (e.g., correlation matrix).
