# %% [markdown]
# # Resilient distributed datasets
# Resilient distributed datasets, or *RDD*s, are the fundamental blocks in PySpark.

# %% [markdown]
# ## What is RDD?
# RDD is essentially a collection of unordered objects,
# - or a mathematical *set*,
# - or a Python list of objects,
# - or similar to a JSON.

# %% [markdown]
# |![rdd-idea](../img/rdd-idea.png)|![math-set](../img/math-set.png)|![json-ex](../img/json-ex.png)|
# | |Fig. Collection of objects| |

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-4.1.1.tar.gz (455.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 MB 11.3 MB/s  0:00:40:00:0100:02
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting py4j<0.10.9.10,>=0.10.9.7 (from pyspark)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (pyproject.toml) ... done
#   Created wheel for pyspark: filename=pyspark-4.1.1-py2.py3-none-any.whl size=456008707 sha256=af103c1fceca8e85cd69dbc4b6a7dae10a15bac2867426e65de09f4d36f3beb6
#   Stored in directory: /Users/liviafingerson/Library/Caches/pip/wheels/f4/ca/ea/203f40b3e935bbf99bee851c2f4a87d22996ab8212d367ce58
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pyspark]m1/2 [pyspark]
# Successfully installed py4j-0.10.9.9 pyspark-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# set up an RDD
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('rddExample').getOrCreate()

### run on colab

# list promoted to RDD
# Out:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
#
# /opt/anaconda3/lib/python3.12/site-packages/pyspark/bin/spark-class: line 97: CMD: bad array subscript
# head: illegal line count -- -1
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 # set up an RDD
#       2 from pyspark.sql import SparkSession
# ----> 4 spark = SparkSession.builder.appName('rddExample').getOrCreate()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/sql/session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/core/context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/core/context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)
#     220         memory_profiler_cls,
#     221     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/core/context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyspark/java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %% [markdown]
# ## Why RDD if we have dataframes?
# - If the data at hand are more *freeformed*, using an RDD allows for storage of various types of objects.
# - Compared to dataframe, which will *attempt* (and fail) to find a common denominator to fit the data above.

# %% [markdown]
# ## Main ingredients of RDD manipulation
# We cover three main building blocks for using RDDs, inheriting the concept of a MapReduce scheme.

# %% [markdown]
# Each of the following building blocks (*functions*) takes a functional input:
# - `map()`
# - `filter()`
# - `reduce()`

# %% [markdown]
# ### `map` through an example
# `map()` applies the given function to each element of the RDD.

# %%
# simple mapping function

# %%
# mapping to the RDD

# %% [markdown]
# **Quick note:**
# - Why did the line throw an error?
# - When was the error thrown?

# %% [markdown]
# **A potential fix:**

# %%
from py4j.protocol import Py4JJavaError

def safer_add_one(value):
    pass # ...

# %% [markdown]
# **Lesson here**:
# - PySpark does not warn you about the content of the RDD.
# - As the developer, we are responsible for how to deal with the data given to an RDD.

# %% [markdown]
# ### `filter` through an example
# `filter()` takes a function that returns `True`/`False` based on any conditions.

# %%
# writing a filtering example

# %% [markdown]
# ### `reduce` through an example
# `reduce()` summarizes the RDD by sequentially applying the given function.
# - similar to `groupby()` in a dataframe.

# %%
# create a new RDD

# example using reduce

# %% [markdown]
# **Warnings about `reduce()`**
# - What functions are reasonable for `reduce()`?
# - *commutative operation*
# - *associative operation*

# %% [markdown]
# **Additional Note:**
#
# A dataframe is actually an RDD, e.g.,

# %%
# Dataframe creation
